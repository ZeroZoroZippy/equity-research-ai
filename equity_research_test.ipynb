# %%
from research_system import EquityResearchSystem
from IPython.display import display, Markdown
import nest_asyncio

# Allow nested async (needed for Jupyter)
nest_asyncio.apply()

# Create the research system
research_system = EquityResearchSystem()

# %%
# In your notebook
from research_system import EquityResearchSystem
import nest_asyncio
from dotenv import load_dotenv

load_dotenv()
nest_asyncio.apply()

research_system = EquityResearchSystem()

# Test with a stock
report = await research_system.research_stock("SWIGGY", "INDIA")
display(Markdown(report))
# Out:
# 🔍 Starting research on SWIGGY...
# ...
#
# 🔌 Connecting to MCP servers...
# ✅ Servers connected!
#
# 📊 Financial Analyst researching...
# 📈 Technical Analyst researching...
# 📰 News Analyst researching (with web search!)...
# ⚖️  Comparative Analyst analyzing peers...
#
# ✍️  Generating research report...
#
# 🧠 Strategic Analyst thinking deeply about implications...
# Error cleaning up server: Attempted to exit a cancel scope that isn't the current tasks's current cancel scope
# ✅ Research complete with strategic analysis!
# Error cleaning up server: Attempted to exit a cancel scope that isn't the current tasks's current cancel scope
# ## Executive Summary
# ...
